# %%
# empezar importando librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# defino funciones para llamarlas luego

def check_nan(df: pd.DataFrame) -> None:
    
    """Recibe un dataframe y enseña el % de valores nulos y lo grafica"""
    
    nan_cols = df.isna().mean() * 100  # porcentaje de nulo en cada columna
    
    display(f'N nan cols: {len(nan_cols[nan_cols>0])}')
    display(nan_cols[nan_cols>0])
    
    
    # grafico de nulos en el dataframe
    plt.figure(figsize=(10, 6))     # inicia la figura y establece el tamaño
    sns.heatmap(df.isna(),          # datos
                yticklabels=False,  # quita las etiquetas del eje y
                cmap='viridis',     # mapa de color
                cbar=False,         # sin barra lateral
               )


    plt.show();

# %%
# importar base de datos 

data = pd.read_csv('attacks.csv', encoding = 'ISO-8859-1')

# %%
data.head() # Ver la base de datos (las primeras filas )
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
data.info() # Mostrar información básica sobre el data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
data.columns # Ver los nombres de las columnas del data frame
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
data.shape # Ver el número de filas y columnas del data frame
# Out:
# (25723, 24)

# %%
data.describe  # Ver estadísticas descriptivas de las columnas numéricas del data frame
# Out:
# <bound method NDFrame.describe of       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# ...

# %%
data.tail(10) # Ver las ultimas filas de la df
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25713         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25714         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25715         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25716         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25717         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25713  ...      NaN                    NaN  NaN          NaN  NaN
# ...

# %%
data.dtypes    # Ver los tipos de datos de cada columna del data frame
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
print(data.isna().sum()) # Identificar los valores faltantes (Nan) en el data frame
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
check_nan(data)
# Out:
# 'N nan cols: 24'
# Case Number               66.170353
# Date                      75.500525
# Year                      75.508300
# Type                      75.516075
# Country                   75.694903
# Area                      77.269370
# Location                  77.599813
# Activity                  77.615364
# Name                      76.316915
# Sex                       77.697003
# Age                       86.506240
# Injury                    75.609377
# Fatal (Y/N)               77.595926
# Time                      88.539439
# Species                   86.533453
# Investigator or Source    75.566614
# pdf                       75.500525
# href formula              75.504412
# href                      75.500525
# Case Number.1             75.500525
# Case Number.2             75.500525
# original order            75.473312
# Unnamed: 22               99.996112
# Unnamed: 23               99.992225
# dtype: float64

# %%
data.columns = data.columns.str.lower() # pongo en lowercase los nombres de las columnas por evitar confusiones mas adelante entre las posibles variables futuras

# %%
data # compruebo los nombres de las columnas que esten realmente en lowercase.
# Out:
#       case number         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area                        location     activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
(data.isna().sum())# Identificar los valores faltantes en el data frame

data.fillna(data.mean(), inplace=True)# Reemplazar los valores faltantes por el valor promedio

data.dropna(thresh= 14, inplace=True) # Eliminar las filas que contengan valores faltantes
# Out:
# C:\Users\FX506\AppData\Local\Temp\ipykernel_13296\3975601773.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)# Reemplazar los valores faltantes por el valor promedio

# %%
data.isnull().sum()
# Out:
# case number                  1
# date                         0
# year                         0
# type                         4
# country                     50
# area                       455
# location                   540
# activity                   544
# name                       210
# sex                        565
# age                       2831
# injury                      28
# fatal (y/n)                539
# time                      3354
# species                   2838
# investigator or source      17
# pdf                          0
# href formula                 1
# href                         0
# case number.1                0
# case number.2                0
# original order               0
# unnamed: 22               6301
# unnamed: 23               6300
# dtype: int64

# %%
data.shape # compruebp la forma que tiene el df
# Out:
# (6302, 24)

# %%
check_nan(data) # aplico la funcion check_nan para ver un grafico de mi df
# Out:
# 'N nan cols: 17'
# case number                0.015868
# type                       0.063472
# country                    0.793399
# area                       7.219930
# location                   8.568708
# activity                   8.632180
# name                       3.332275
# sex                        8.965408
# age                       44.922247
# injury                     0.444303
# fatal (y/n)                8.552840
# time                      53.221200
# species                   45.033323
# investigator or source     0.269756
# href formula               0.015868
# unnamed: 22               99.984132
# unnamed: 23               99.968264
# dtype: float64

# %%
data['year'] = data['year'].fillna(0) # lleno los valores nan por '0' en la columna year

# %%
data['original order'] = data['original order'].fillna(0) # lleno los valores nan por '0' en la columna original order

# %%
data = data.fillna('unknown') # relleno los valores nulos de strings por unknown

# %%
check_nan(data)
# Out:
# 'N nan cols: 0'
# Series([], dtype: float64)

# %%
data[['case number.1', 'case number.2']] = 'rellenar' # cambio los valores de las columnas 'case number 1' y 'case number 2'

# %%
data['href formula'].iloc[0]
# Out:
# 'http://sharkattackfile.net/spreadsheets/pdf_directory/2018.06.25-Wolfe.pdf'

# %%
po=data[['href','href formula']].T # compruebo que no hayan duplicados en columnas similares
po.duplicated()
# Out:
# href            False
# href formula    False
# dtype: bool

# %%
data[['href','href formula']].duplicated().all() # vuelvo a comprobar que o hayan duplicados
# Out:
# False

# %%
n_fila = data.shape[0] # hago un for loop para cambiar los valores de 'case number' por orden del 1 al ..... en index [0]

for i in range(n_fila):
    data.loc[i, 'case number'] = n_fila - i

# %%
data['year'].value_counts()
# Out:
# 2015.0    143
# 2017.0    136
# 2016.0    130
# 2011.0    128
# 2014.0    127
#          ...
# 1785.0      1
# 1784.0      1
# 1783.0      1
# 1780.0      1
# 1792.0      1
# Name: year, Length: 250, dtype: int64

# %%
data.shape # compruebo la forma de mi df de nuevo
# Out:
# (6302, 24)

# %%
def quitar_punto_cero(numero):
    return str(numero).rstrip('.0')

# %%
check_nan(data)
# Out:
# 'N nan cols: 0'
# Series([], dtype: float64)

# %%
data['sex '].unique() # reviso los valores unicos de las columnas para VER
# Out:
# array(['F', 'M', 'unknown', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
data['sex '].unique()
# Out:
# array(['F', 'M', 'unknown', 'M ', 'lli', 'N', '.'], dtype=object)

# %%
data['sex '].replace(['M ', 'lli', 'N', '.'], ['unknown', 'unknown', 'unknown', 'unknown'], inplace=True)

# %%
data['sex '].unique() # compruebo que todo lo de antes funcione
# Out:
# array(['F', 'M', 'unknown'], dtype=object)

# %%
def time_of_day(hour): # funcion para agrupar y asi reducir la cantidad de horas del dia en periodos preestablecidos
    
    if '07' in hour or '08' in hour or '09' in hour or '10' in hour or '11' in hour or '12' in hour:
        return 'Morning'
    elif '13' in hour or '14' in hour or '15' in hour or '16' in hour or '17' in hour or '18' in hour or '19' in hour or '20' in hour or '21' in hour:
        return 'Afternoon'
    elif '22' in hour or '23' in hour or '00' in hour or '01' in hour or '02' in hour or '03' in hour or '04' in hour or '05' in hour or '06' in hour:
        return 'Night'
    else:
        return 'No information'

data['time'] = data['time'].apply(time_of_day)

# %%
data.time.unique() # compruebo que funcione la funcion revisando sus datos unicos
# Out:
# array(['Afternoon', 'Morning', 'No information', 'Night'], dtype=object)

# %%
data['activity'].unique()
# Out:
# array(['Paddling', 'Standing', 'Surfing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
data['age'].unique()
# Out:
# array(['57', '11', '48', 'unknown', '18', '52', '15', '12', '32', '10',
#        '21', '34', '30', '60', '33', '29', '54', '41', '37', '56', '19',
#        '25', '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20',
#        '24', '26', '49', '22', '7', '31', '17', '40', '13', '42', '3',
#        '8', '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
# ...

# %%
data['area'].unique()
# Out:
# array(['California', 'Georgia', 'Hawaii', 'New South Wales', 'Colima',
#        'Pernambuco', 'Florida', 'Queensland', 'South Carolina',
#        'Cornwall', 'Westerm Australia', 'Eastern Cape Province',
#        'Hua Hin', 'Cocos Island', 'Western Australia',
#        'Alifu Alifu Atoll', 'Western Cape Province', 'New Providence',
#        'Alagoas', 'unknown', 'Victoria', 'KwaZulu-Natal',
#        'Boi Island, Victoria', 'Galapagos Islands', 'Fernando de Noronha',
#        'Sepang', 'Holquin Province', 'Pamplemousses ', 'South Australia',
#        'North Island', 'New York', 'Canary Islands', ' Upolu Island',
#        'Shizuoka Prefecture', 'Texas', 'Castellón', 'Massachusetts',
#        'Red Sea Protectorate', 'New Providence District',
#        '40 miles off Grand Bahama Island', 'Ascension Island',
#        'New Jersey', 'Majorca', 'Washington', 'Tabasco', 'Anjouan',
#        'Ibiza Island', 'Marquesas', 'South Devon', 'New Providence ',
# ...

# %%
data['location'].unique()
# Out:
# array(['Oceanside, San Diego County', 'St. Simon Island, Glynn County',
#        'Habush, Oahu', ..., 'Ocracoke Inlet', 'Panama Bay 8ºN, 79ºW',
#        'Below the English fort, Trincomalee'], dtype=object)

# %%
data
# Out:
#      case number         date    year        type             country  \
# 0           6302  25-Jun-2018  2018.0     Boating                 USA
# 1           6301  18-Jun-2018  2018.0  Unprovoked                 USA
# 2           6300  09-Jun-2018  2018.0     Invalid                 USA
# 3           6299  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4           6298  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297           5  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298           4  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299           3    1900-1905     0.0  Unprovoked                 USA
# 6300           2    1883-1889     0.0  Unprovoked              PANAMA
# 6301           1    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# ...
